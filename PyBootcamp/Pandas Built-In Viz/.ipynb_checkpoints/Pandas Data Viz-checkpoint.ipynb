# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df1 = pd.read_csv('df1')
df2 = pd.read_csv('df2')
df = pd.DataFrame(np.random.randn(1000,2),columns = ['a','b'])

# %%
df1.head()
# Out:
#    Unnamed: 0         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
#making a histogram off a column
df1['A'].hist()

# %%
#making a barplot
df2.plot(kind='bar',figsize=(12,3))
#instead of using kind to specify the type of plot we want, we can call 'em directly

# %%
df2.plot.hist()

# %%
df2.plot.area(alpha=0.5)
#alpha changes transparency

# %%
df2.plot.bar(stacked=True)

# %%
df2.plot.line(x='a',y='b')

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*100)
# Out:
# /home/dhruvatara/.local/lib/python3.6/site-packages/matplotlib/collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df1.plot.box()

# %%
df2.plot.hexbin(x='a',y='b',gridsize=50)

# %%
df2.plot.kde()
